# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN =282.7
AUD1_MEAN =424.4
VIS1_STD =46.65
AUD1_STD =35.87

# %%
# build a bar plot
plt.bar(['Juan  Visual', 'Juan  Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (miliseconds)')
plt.xlabel("Reaction Type")
plt.title('Reaction Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reaction Speed, Visual vs. Auditory')
